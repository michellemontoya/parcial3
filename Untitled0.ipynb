# %% [markdown]
# <a href="https://colab.research.google.com/github/michellemontoya/parcial3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Usuario:
    def usuario(self):
        print("////////////BIBLIOTECA EL SABER DE LAS PALABRAS////////////")

        print("-----------------------Bienvenido------------------")
       
        print("===============================================")
        print("digite sus datos para crear una cuenta")
        print("===============================================")

        self.nombres = str(input("Escriba su nombre: "))
        self.apellidos = str(input("Escriba su apellido: "))
        self.telefono = int(input("Escriba su numero de telefono: "))
        self.edad = int(input("Escriba su edad: "))
        self.contrasena = input("Cree una contraseña: ")
        self.usuario = input("Digite su usuario:")
        print("------------CUENTA CREADA CORRECTAMENTE-------------")

        print("----------------------------------------------------")


class Entrada(Usuario):
    def __init__(self):
        super().usuario()
        print("datos para iniciar secion en la biblioteca: ")
        self._nombreuser=str(input("\tEscriba su usuario : "))
        self._contrasenauser=str(input("\tEscriba su contraseña : "))        
        if self._nombreuser==self.usuario and self._contrasenauser==self.contrasena:

            print("==================================================")
            print(" ===============BIENVENIDO===========\n\
             haz iniciado secion CORRECTAMENTE.")
            
        else:
            print("OJO!!\n\
            contraseña o usuario incorrecto, por su seguridad debes volver a iniciar secion")
            exit()
d=Entrada()


print("____________________________________________________________________________")


class Persona(Usuario):
  def _init_(self):
    self.__Autor=""
    self.__Isbn=""
    self.__Paginas=""
    self.__Editorial=""
    self.__Edicion=""
    self.__Pais=""

  def GetAutor(self):
    return self.__Autor

  def SetAutor(self, autor):
    self.__Autor= autor

  def GetIsbn(self):
    return self.__Isbn
  
  def SetIsbn(self, isbn):
    self.__Isbn = isbn

  def GetPaginas(self):
    return self.__Paginas
  

  def SetPaginas(self, paginas):
    self.__Paginas = paginas

  def GetEditorial(self):
    return self.__Editorial
  
  def SetEditorial(self, editorial):
    self.__Editorial = editorial
  
  def GetEdicion(self):
    return self.__Edicion
  
  def SetEdicion(self, edicion):
    self.__Edicion = edicion
  
  def GetPais(self):
    return self.__Pais
  
  def SetPais(self, pais):
    self.__Pais = pais
  print("\n")
  print("ESTOS SON LOS LIBROS QUE TENEMOS DIASPONIBLE")
  print("\n")

  def MostrarInformacion(self):
    print("\tLibro 1, El mejor enemigo del mundo:")
    print("\tAutor:",self.GetAutor())
    print("\tIsbn:",self.GetIsbn())
    print("\tPaginas:",self.GetPaginas())
    print("\tEditorial:",self.GetEditorial())
    print("\tEdicion:",self.GetEdicion())
    print("\tPais:",self.GetPais())
    
c=Persona()
c.SetAutor("Julio Mendoza")
c.SetIsbn("0-13-015988-X")
c.SetPaginas("257pg")
c.SetEditorial("Mexico,Tijuana ")
c.SetEdicion("2a. edición")
c.SetPais("(Mexico)")
c.MostrarInformacion()

class Fecha(Usuario and Persona):

  def _init_(self):
    self.__Fecha="0"
  
  def GetFecha(self):
    return self.__Fecha

  def SetFecha(self, fecha):
    self.__Fecha = fecha
  
  def MostrarFecha(self):
    print("\tFecha: ",self.GetFecha())

f=Fecha()
f.SetFecha("15/8/2022")
f.MostrarFecha()

class inf(Persona):
  def _init_(self):
    self.__Autor=""
    self.__Isbn=""
    self.__Paginas=""
    self.__Editorial=""
    self.__Edicion=""
    self.__Pais=""
    self.__Creado=""

  def GetAutor(self):
    return self.__Autor

  def SetAutor(self, autor):
    self.__Autor= autor

  def GetIsbn(self):
    return self.__Isbn
  
  def SetIsbn(self, isbn):
    self.__Isbn = isbn

  def GetPaginas(self):
    return self.__Paginas
  
  def SetPaginas(self, paginas):
    self.__Paginas = paginas

  def GetEditorial(self):
    return self.__Editorial
  
  def SetEditorial(self, editorial):
    self.__Editorial = editorial
  
  def GetEdicion(self):
    return self.__Edicion
  
  def SetEdicion(self, edicion):
    self.__Edicion = edicion
  
  def GetPais(self):
    return self.__Pais
  
  def SetPais(self, pais):
    self.__Pais = pais
  
  def GetCreado(self):
    return self.__Creado

  def SetCreado(self, creado):
    self.__Creado = creado

  def Ver_otro_libro(self):
    print("\tLibro 2, Alicia el pais de las maravillas: ")
    print("\tAutor:",self.GetAutor())
    print("\tIsbn:",self.GetIsbn())
    print("\tPaginas:",self.GetPaginas())
    print("\tEditorial:",self.GetEditorial())
    print("\tEdicion:",self.GetEdicion())
    print("\tPais:",self.GetPais())
    print("\tCreado:",self.GetCreado())
    print("\n")
print("--------------------------------------------------------")
l=inf()
l.SetAutor("Liang, Y. Daniel")
l.SetIsbn("0-13-031997-X")
l.SetPaginas("2359")
l.SetEditorial("Prentice-Hall, New Jersey ")
l.SetEdicion("3a. edición")
l.SetPais("(USA)")
l.SetCreado("Creado por los estados unidos")
l.Ver_otro_libro()



class inf2(Persona):
  def _init_(self):
    self.__Autor=""
    self.__Isbn=""
    self.__Paginas=""
    self.__Editorial=""
    self.__Edicion=""
    self.__Pais=""
    self.__Creado=""

  def GetAutor(self):
    return self.__Autor

  def SetAutor(self, autor):
    self.__Autor= autor

  def GetIsbn(self):
    return self.__Isbn
  
  def SetIsbn(self, isbn):
    self.__Isbn = isbn

  def GetPaginas(self):
    return self.__Paginas
  
  def SetPaginas(self, paginas):
    self.__Paginas = paginas

  def GetEditorial(self):
    return self.__Editorial
  
  def SetEditorial(self, editorial):
    self.__Editorial = editorial
  
  def GetEdicion(self):
    return self.__Edicion
  
  def SetEdicion(self, edicion):
    self.__Edicion = edicion
  
  def GetPais(self):
    return self.__Pais
  
  def SetPais(self, pais):
    self.__Pais = pais
  
  def GetCreado(self):
    return self.__Creado

  def SetCreado(self, creado):
    self.__Creado = creado
  
  def Ver_otro_libro1(self):
    print("\tLibro 3, 100 años de soledad: ")
    print("\tAutor:",self.GetAutor())
    print("\tIsbn:",self.GetIsbn())
    print("\tPaginas:",self.GetPaginas())
    print("\tEditorial:",self.GetEditorial())
    print("\tEdicion:",self.GetEdicion())
    print("\tPais:",self.GetPais())
    print("\tCreado:",self.GetCreado())
print("-----------------------------------------------------------------------")

l=inf2()
l.SetAutor("Gabriel garcia marquez ")
l.SetIsbn("0-13-031997-X")
l.SetPaginas("3102pg")
l.SetEditorial("palacio de justicia ")
l.SetEdicion("3a. edición  original")
l.SetPais("(Colombia)")
l.SetCreado("Creado en BOGOTA COLOMBIA")

l.Ver_otro_libro1()

print("selecciona el libro que te quieres llevar")

class Prestar():
   def __init__(self):

          super().__init__()
          total=0

          comprobar= True
          while comprobar == True:
            print("\n")
            print("  LIBROS\n\
            1. -el mejor enemigo del mundo\n\
            2. -alicia y el pais de las maravillas\n\
            3. -100 años de soledad\n")


            opcion=int(input("INGRESE LA OPCION QUE DESEAS : "))


            

            if opcion==1:
                print("\tlibro prestado, vuelve pronto.")
                return
                
            if opcion==2:
                print("\tlibro prestado, vuelve pronto.")
                return
                
            if opcion==3:
                print("\tlibro prestado, vuelve pronto.")
                return
            

l=Prestar()
print("tienes 20 dias para devolverlo")
# Out:
# ////////////BIBLIOTECA EL SABER DE LAS PALABRAS////////////
# -----------------------Bienvenido------------------
# ...
# digite sus datos para crear una cuenta
# ...
# Escriba su nombre: danna
# Escriba su apellido: montoya
# Escriba su numero de telefono: 3144432212
# Escriba su edad: 18
# Cree una contraseña: danna
# Digite su usuario:mich
# ------------CUENTA CREADA CORRECTAMENTE-------------
# ----------------------------------------------------
# datos para iniciar secion en la biblioteca:
# 	Escriba su usuario : mich
# 	Escriba su contraseña : danna
# ...
#  ===============BIENVENIDO===========
#              haz iniciado secion CORRECTAMENTE.
# ____________________________________________________________________________
#
#
#
#
# ESTOS SON LOS LIBROS QUE TENEMOS DIASPONIBLE
#
#
# 	Libro 1, El mejor enemigo del mundo:
# 	Autor: Julio Mendoza
# 	Isbn: 0-13-015988-X
# 	Paginas: 257pg
# 	Editorial: Mexico,Tijuana
# 	Edicion: 2a. edición
# 	Pais: (Mexico)
# 	Fecha:  15/8/2022
# ...
